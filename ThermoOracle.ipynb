# %%
# Data Processing
import pandas as pd
import numpy as np
import datetime

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
from sklearn.preprocessing import MinMaxScaler

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %%
data=pd.read_csv("weatherHistory.csv")

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.drop('Loud Cover',axis=1)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.head(Daily Summary)
# Out:
#                   Formatted Date        Summary Precip Type  Humidity  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain      0.89
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain      0.86
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain      0.89
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain      0.83
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain      0.83
#
#    Wind Bearing (degrees)  Visibility (km)  Wind Speed (km/h)  \
# 0                   251.0          15.8263            14.1197
# 1                   259.0          15.8263            14.2646
# 2                   204.0          14.9569             3.9284
# 3                   269.0          15.8263            14.1036
# 4                   259.0          15.8263            11.0446
#
#    Pressure (millibars)                      Daily Summary  Temperature (C)  \
# 0               1015.13  Partly cloudy throughout the day.         9.472222
# ...

# %%
le = LabelEncoder()
data["Summary"] = le.fit_transform(data["Summary"])
data["Precip Type"] = le.fit_transform(data["Precip Type"])
data["Daily Summary"] = le.fit_transform(data["Daily Summary"])
data.corr()["Temperature (C)"]
# Out:
# C:\Users\sethp\AppData\Local\Temp\ipykernel_16840\2499864205.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()["Temperature (C)"]
# Summary                     0.146658
# Precip Type                -0.520381
# Temperature (C)             1.000000
# Apparent Temperature (C)    0.992629
# Humidity                   -0.632255
# Wind Speed (km/h)           0.008957
# Wind Bearing (degrees)      0.029988
# Visibility (km)             0.392847
# Loud Cover                       NaN
# Pressure (millibars)       -0.005447
# Daily Summary               0.438879
# Name: Temperature (C), dtype: float64

# %%
data.head()
# Out:
#                   Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200       19            0         9.472222
# 1  2006-04-01 01:00:00.000 +0200       19            0         9.355556
# 2  2006-04-01 02:00:00.000 +0200       17            0         9.377778
# 3  2006-04-01 03:00:00.000 +0200       19            0         8.288889
# 4  2006-04-01 04:00:00.000 +0200       17            0         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data=data[['Formatted Date','Summary','Precip Type','Humidity','Wind Speed (km/h)','Wind Bearing (degrees)','Visibility (km)','Pressure (millibars)','Temperature (C)']]

# %%
data.head()
# Out:
#                   Formatted Date  Summary  Precip Type  Humidity  \
# 0  2006-04-01 00:00:00.000 +0200       19            0      0.89
# 1  2006-04-01 01:00:00.000 +0200       19            0      0.86
# 2  2006-04-01 02:00:00.000 +0200       17            0      0.89
# 3  2006-04-01 03:00:00.000 +0200       19            0      0.83
# 4  2006-04-01 04:00:00.000 +0200       17            0      0.83
#
#    Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0            14.1197                   251.0          15.8263
# 1            14.2646                   259.0          15.8263
# 2             3.9284                   204.0          14.9569
# 3            14.1036                   269.0          15.8263
# 4            11.0446                   259.0          15.8263
#
#    Pressure (millibars)  Temperature (C)
# 0               1015.13         9.472222
# 1               1015.63         9.355556
# 2               1015.94         9.377778
# ...

# %%
data['Formatted Date']=pd.to_datetime(data['Formatted Date'],utc=True).dt.hour
# data['Formatted Date']=data['Formatted Date'].dt.hour

# %%
data.head()
# Out:
#    Formatted Date  Summary  Precip Type  Humidity  Wind Speed (km/h)  \
# 0              22       19            0      0.89            14.1197
# 1              23       19            0      0.86            14.2646
# 2               0       17            0      0.89             3.9284
# 3               1       19            0      0.83            14.1036
# 4               2       17            0      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# 1                   259.0          15.8263               1015.63
# 2                   204.0          14.9569               1015.94
# 3                   269.0          15.8263               1016.41
# 4                   259.0          15.8263               1016.51
#
#    Temperature (C)
# 0         9.472222
# 1         9.355556
# 2         9.377778
# 3         8.288889
# 4         8.755556

# %%
X = data.drop(columns =['Temperature (C)'])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
 
X["Summary"] = scaler.fit_transform(X[["Summary"]])
X["Humidity"] = scaler.fit_transform(X[["Humidity"]])
X["Wind Speed (km/h)"] = scaler.fit_transform(X[["Wind Speed (km/h)"]])
X["Wind Bearing (degrees)"] = scaler.fit_transform(X[["Wind Bearing (degrees)"]])
X["Visibility (km)"] = scaler.fit_transform(X[["Visibility (km)"]])
X["Pressure (millibars)"] = scaler.fit_transform(X[["Pressure (millibars)"]])

# %%
X.head()
# Out:
#    Formatted Date   Summary  Precip Type  Humidity  Wind Speed (km/h)  \
# 0              22  0.730769            0      0.89           0.221130
# 1              23  0.730769            0      0.86           0.223399
# 2               0  0.653846            0      0.89           0.061523
# 3               1  0.730769            0      0.83           0.220877
# 4               2  0.653846            0      0.83           0.172970
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)
# 0                0.699164            0.983              0.970135
# 1                0.721448            0.983              0.970613
# 2                0.568245            0.929              0.970909
# 3                0.749304            0.983              0.971358
# 4                0.721448            0.983              0.971454

# %%
y=pd.DataFrame(data['Temperature (C)'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,test_size=0.25,shuffle=True)

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# C:\Users\sethp\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 3.4723046017527848
# Mean Squared Error: 20.81146339204942
# R-squared: 0.7726760004588844
